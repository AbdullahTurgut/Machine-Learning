# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data-gym.csv')

# %%
df.head()
# Out:
#    number_people                       date  timestamp  day_of_week  \
# 0             37  2015-08-14 17:00:11-07:00      61211            4
# 1             45  2015-08-14 17:20:14-07:00      62414            4
# 2             40  2015-08-14 17:30:15-07:00      63015            4
# 3             44  2015-08-14 17:40:16-07:00      63616            4
# 4             45  2015-08-14 17:50:17-07:00      64217            4
#
#    is_weekend  is_holiday  temperature  is_start_of_semester  \
# 0           0           0        71.76                     0
# 1           0           0        71.76                     0
# 2           0           0        71.76                     0
# 3           0           0        71.76                     0
# 4           0           0        71.76                     0
#
#    is_during_semester  month  hour
# 0                   0      8    17
# 1                   0      8    17
# 2                   0      8    17
# 3                   0      8    17
# ...

# %%
df.shape
# Out:
# (62184, 11)

# %%
df.columns
# Out:
# Index(['number_people', 'date', 'timestamp', 'day_of_week', 'is_weekend',
#        'is_holiday', 'temperature', 'is_start_of_semester',
#        'is_during_semester', 'month', 'hour'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62184 entries, 0 to 62183
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   number_people         62184 non-null  int64
#  1   date                  62184 non-null  object
#  2   timestamp             62184 non-null  int64
#  3   day_of_week           62184 non-null  int64
#  4   is_weekend            62184 non-null  int64
#  5   is_holiday            62184 non-null  int64
#  6   temperature           62184 non-null  float64
#  7   is_start_of_semester  62184 non-null  int64
#  8   is_during_semester    62184 non-null  int64
#  9   month                 62184 non-null  int64
#  10  hour                  62184 non-null  int64
# dtypes: float64(1), int64(9), object(1)
# memory usage: 5.2+ MB

# %%
df.describe()
# Out:
#        number_people     timestamp   day_of_week    is_weekend    is_holiday  \
# count   62184.000000  62184.000000  62184.000000  62184.000000  62184.000000
# mean       29.072543  45799.437958      2.982504      0.282870      0.002573
# std        22.689026  24211.275891      1.996825      0.450398      0.050660
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         9.000000  26624.000000      1.000000      0.000000      0.000000
# 50%        28.000000  46522.500000      3.000000      0.000000      0.000000
# 75%        43.000000  66612.000000      5.000000      1.000000      0.000000
# max       145.000000  86399.000000      6.000000      1.000000      1.000000
#
#         temperature  is_start_of_semester  is_during_semester         month  \
# count  62184.000000          62184.000000        62184.000000  62184.000000
# mean      58.557108              0.078831            0.660218      7.439824
# ...

# %%
df.isnull().sum()
# Out:
# number_people           0
# date                    0
# timestamp               0
# day_of_week             0
# is_weekend              0
# is_holiday              0
# temperature             0
# is_start_of_semester    0
# is_during_semester      0
# month                   0
# hour                    0
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'],utc=True)

# %%
df.head()
# Out:
#    number_people                      date  timestamp  day_of_week  \
# 0             37 2015-08-15 00:00:11+00:00      61211            4
# 1             45 2015-08-15 00:20:14+00:00      62414            4
# 2             40 2015-08-15 00:30:15+00:00      63015            4
# 3             44 2015-08-15 00:40:16+00:00      63616            4
# 4             45 2015-08-15 00:50:17+00:00      64217            4
#
#    is_weekend  is_holiday  temperature  is_start_of_semester  \
# 0           0           0        71.76                     0
# 1           0           0        71.76                     0
# 2           0           0        71.76                     0
# 3           0           0        71.76                     0
# 4           0           0        71.76                     0
#
#    is_during_semester  month  hour
# 0                   0      8    17
# 1                   0      8    17
# 2                   0      8    17
# 3                   0      8    17
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62184 entries, 0 to 62183
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   number_people         62184 non-null  int64
#  1   date                  62184 non-null  datetime64[ns, UTC]
#  2   timestamp             62184 non-null  int64
#  3   day_of_week           62184 non-null  int64
#  4   is_weekend            62184 non-null  int64
#  5   is_holiday            62184 non-null  int64
#  6   temperature           62184 non-null  float64
#  7   is_start_of_semester  62184 non-null  int64
#  8   is_during_semester    62184 non-null  int64
#  9   month                 62184 non-null  int64
#  10  hour                  62184 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(1), int64(9)
# memory usage: 5.2 MB

# %%
df['date'].dt.year
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 62179    2017
# 62180    2017
# 62181    2017
# 62182    2017
# 62183    2017
# Name: date, Length: 62184, dtype: int32

# %%
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#    number_people                      date  timestamp  day_of_week  \
# 0             37 2015-08-15 00:00:11+00:00      61211            4
# 1             45 2015-08-15 00:20:14+00:00      62414            4
# 2             40 2015-08-15 00:30:15+00:00      63015            4
# 3             44 2015-08-15 00:40:16+00:00      63616            4
# 4             45 2015-08-15 00:50:17+00:00      64217            4
#
#    is_weekend  is_holiday  temperature  is_start_of_semester  \
# 0           0           0        71.76                     0
# 1           0           0        71.76                     0
# 2           0           0        71.76                     0
# 3           0           0        71.76                     0
# 4           0           0        71.76                     0
#
#    is_during_semester  month  hour  year
# 0                   0      8    17  2015
# 1                   0      8    17  2015
# 2                   0      8    17  2015
# ...

# %%
df['year'].unique()
# Out:
# array([2015, 2016, 2017], dtype=int32)

# %%
df.drop('date',axis=1,inplace=True)

# %%
df.head()
# Out:
#    number_people  timestamp  day_of_week  is_weekend  is_holiday  temperature  \
# 0             37      61211            4           0           0        71.76
# 1             45      62414            4           0           0        71.76
# 2             40      63015            4           0           0        71.76
# 3             44      63616            4           0           0        71.76
# 4             45      64217            4           0           0        71.76
#
#    is_start_of_semester  is_during_semester  month  hour  year
# 0                     0                   0      8    17  2015
# 1                     0                   0      8    17  2015
# 2                     0                   0      8    17  2015
# 3                     0                   0      8    17  2015
# 4                     0                   0      8    17  2015

# %%
sns.lineplot(data=df,x="hour",y="number_people",ci=None)
plt.title("Saatlik ortalama insan sayısı")
plt.show()
# Out:
# C:\Users\Alcor\AppData\Local\Temp\ipykernel_10932\2167245361.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df,x="hour",y="number_people",ci=None)

# %%
sns.barplot(data=df,x="day_of_week",y="number_people")
plt.title("Günlere göre ortalama insan sayısı")
plt.show()

# %%
sns.regplot(data=df,x="temperature",y="number_people")
plt.show()

# %%
sns.boxplot(data=df,x="is_start_of_semester",y="number_people")
plt.title("Dönem başında insan sayısı")
plt.show()

# %%
df.corr()
# Out:
#                       number_people  day_of_week  is_weekend  is_holiday  \
# number_people              1.000000    -0.162062   -0.173958   -0.048249
# day_of_week               -0.162062     1.000000    0.791338   -0.075862
# is_weekend                -0.173958     0.791338    1.000000   -0.031899
# is_holiday                -0.048249    -0.075862   -0.031899    1.000000
# temperature                0.373327     0.011169    0.020673   -0.088527
# is_start_of_semester       0.182683    -0.011782   -0.016646   -0.014858
# is_during_semester         0.335350    -0.004824   -0.036127   -0.070798
# month                     -0.097854     0.015559    0.008462   -0.094942
# hour                       0.552049    -0.001914   -0.000517    0.002843
# year                      -0.322591    -0.021242   -0.021260    0.121129
#
#                       temperature  is_start_of_semester  is_during_semester  \
# number_people            0.373327              0.182683            0.335350
# ...

# %%
df.drop('timestamp',axis=1,inplace=True)

# %%
df.head()
# Out:
#    number_people  day_of_week  is_weekend  is_holiday  temperature  \
# 0             37            4           0           0        71.76
# 1             45            4           0           0        71.76
# 2             40            4           0           0        71.76
# 3             44            4           0           0        71.76
# 4             45            4           0           0        71.76
#
#    is_start_of_semester  is_during_semester  month  hour  year
# 0                     0                   0      8    17  2015
# 1                     0                   0      8    17  2015
# 2                     0                   0      8    17  2015
# 3                     0                   0      8    17  2015
# 4                     0                   0      8    17  2015

# %%
# dependent & independent feature

# %%
X = df.drop('number_people',axis=1)
y = df['number_people']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=15)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
def calculate_model_metrics(true,predicted):
    mae = mean_absolute_error(true,predicted)
    mse = mean_squared_error(true,predicted)
    rmse = np.sqrt(mean_squared_error(true,predicted))
    r2_scresult = r2_score(true,predicted) 
    return mae, rmse, r2_scresult

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge" : Ridge(),
    "K-Neighbors Regressor" : KNeighborsRegressor(),
    "Decision Tree" : DecisionTreeRegressor(),
    "Random Forest Regressor" : RandomForestRegressor()
}

# %%
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train,y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    model_train_mae, model_train_rmse, model_train_scresult = calculate_model_metrics(y_train,y_train_pred)
    model_test_mae, model_test_rmse, model_test_scresult = calculate_model_metrics(y_test,y_test_pred)

    print(list(models.values())[i])

    print("Evaluation for training set")
    print("RMSE : ", model_train_rmse)
    print("Mean ab err : ", model_train_mae)
    print("R2 score : ", model_train_scresult)

    print("-----------------------------------")
    
    print("Evaluation for test set")
    print("RMSE : ", model_test_rmse)
    print("Mean ab err : ", model_test_mae)
    print("R2 score : ", model_test_scresult)
    
    print("-----------------------------------")
    print("\n")
# Out:
# LinearRegression()
# Evaluation for training set
# RMSE :  14.322500408269727
# Mean ab err :  10.733469936454318
# R2 score :  0.5999639521710997
# -----------------------------------
# Evaluation for test set
# RMSE :  14.45063290337055
# Mean ab err :  10.779752371029556
# R2 score :  0.5989271376662775
# -----------------------------------
#
#
# Lasso()
# Evaluation for training set
# RMSE :  14.569122351126818
# Mean ab err :  10.945189874221992
# R2 score :  0.5860687429058036
# -----------------------------------
# Evaluation for test set
# RMSE :  14.703511215751082
# Mean ab err :  10.970594902476911
# R2 score :  0.5847671974050241
# -----------------------------------
#
#
# Ridge()
# Evaluation for training set
# RMSE :  14.322500413912243
# Mean ab err :  10.733479178820696
# R2 score :  0.5999639518559021
# -----------------------------------
# Evaluation for test set
# RMSE :  14.450633329986024
# Mean ab err :  10.779759559023008
# R2 score :  0.5989271139851151
# ...
